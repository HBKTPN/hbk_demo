# %%
import pandas as pd

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.loc[767]
# Out:
# Pregnancies                  1.000
# Glucose                     93.000
# BloodPressure               70.000
# SkinThickness               31.000
# Insulin                      0.000
# BMI                         30.400
# DiabetesPedigreeFunction     0.315
# Age                         23.000
# Outcome                      0.000
# Name: 767, dtype: float64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35    250.0  33.6
# 1            1       85             66             29    300.0  26.6
# 2            8      183             64              0      NaN  23.3
# 3            1       89             66             23     94.0  28.1
# 4            0      137             40             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.BloodPressure.head(5)
# Out:
# 0    72
# 1    66
# 2    64
# 3    66
# 4    40
# Name: BloodPressure, dtype: int64

# %%
#df_local=pd.read_csv(r"C:\Users\Sai_Prithvi\Downloads\sample-salesv2.csv",header=None)

# %%
df1=df.sum()

# %%
df1
# Out:
# Pregnancies                  2953.000
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     62236.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
df2=df[['Glucose','Age']].mean()

# %%
df2
# Out:
# Glucose    120.894531
# Age         33.240885
# dtype: float64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df3=df[['Glucose','Age']].min()

# %%
df3
# Out:
# Glucose     0
# Age        21
# dtype: int64

# %%
sum=df.iloc[0:2].sum()

# %%
sum
# Out:
# Pregnancies                   7.000
# Glucose                     233.000
# BloodPressure               138.000
# SkinThickness                64.000
# Insulin                     550.000
# BMI                          60.200
# DiabetesPedigreeFunction      0.978
# Age                          81.000
# Outcome                       1.000
# dtype: float64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35    250.0  33.6
# 1            1       85             66             29    300.0  26.6
# 2            8      183             64              0      NaN  23.3
# 3            1       89             66             23     94.0  28.1
# 4            0      137             40             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35    250.0  33.6
# 1            1       85             66             29    300.0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.Pregnancies.head(5)
# Out:
# 0    6
# 1    1
# 2    8
# 3    1
# 4    0
# Name: Pregnancies, dtype: int64

# %%
df['Pregnancies'].mean()
# Out:
# 3.8450520833333335

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['newcolumnA']=df['BloodPressure']+df['Glucose']

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  newcolumnA
# 0                       0.627   50        1         220
# ...

# %%
dfnew=df.drop(['newcolumnA'],axis='columns')

# %%
dfnew.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35    250.0  33.6
# 1            1       85             66             29    300.0  26.6
# 2            8      183             64              0      NaN  23.3
# 3            1       89             66             23     94.0  28.1
# 4            0      137             40             35    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1=pd.read_csv("diabetes.csv",header=None)

# %%
df1.head()
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35      250  33.6
# 2            1       85             66             29      300  26.6
# 3            8      183             64              0      NaN  23.3
# 4            1       89             66             23       94  28.1
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#excel and json you can try it.

# %%
# Import pandas library
import pandas as pd

# initialize list elements
data = [10,20,30,40,50,60]

# Create the pandas DataFrame with column name is provided explicitly
df_new = pd.DataFrame(data, columns=['Numbers'])

# print dataframe.
df_new
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60

# %%
df_new.to_csv("output.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.Pregnancies.head(3)
# Out:
# 0    6
# 1    1
# 2    8
# Name: Pregnancies, dtype: int64

# %%
df["Pregnancies"]
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64

# %%
df[["Pregnancies","Glucose"]]
# Out:
#      Pregnancies  Glucose
# 0              6      148
# 1              1       85
# 2              8      183
# 3              1       89
# 4              0      137
# ..           ...      ...
# 763           10      101
# 764            2      122
# 765            5      121
# 766            1      126
# 767            1       93
#
# [768 rows x 2 columns]

# %%
df['newcolumn']=df["Pregnancies"]+df["Glucose"]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    250.0  33.6
# 1              1       85             66             29    300.0  26.6
# 2              8      183             64              0      NaN  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  newcolumn
# 0                       0.627   50        1        154
# ...

# %%
df.drop(['BMI'],axis='columns')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35    250.0
# 1              1       85             66             29    300.0
# 2              8      183             64              0      NaN
# 3              1       89             66             23     94.0
# 4              0      137             40             35    168.0
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48    180.0
# 764            2      122             70             27      0.0
# 765            5      121             72             23    112.0
# 766            1      126             60              0      0.0
# 767            1       93             70             31      0.0
#
#      DiabetesPedigreeFunction  Age  Outcome  newcolumn
# 0                       0.627   50        1        154
# 1                       0.351   31        0         86
# ...

# %%
#update

import pandas as pd

df1 = pd.DataFrame([["Emil", "Tobias", "Linus"], [16, 14, 10]])
df2 = pd.DataFrame([["Emil"], [17]])

# %%
df1
# Out:
#       0       1      2
# 0  Emil  Tobias  Linus
# 1    16      14     10

# %%
df2
# Out:
#       0
# 0  Emil
# 1    17

# %%
df1.update(df2)

# %%
df1
# Out:
#       0       1      2
# 0  Emil  Tobias  Linus
# 1    17      14     10

# %%
import numpy as np
import pandas as pd


A = pd.DataFrame({'Sr.no': ['1', '2', '3', '4', '5'],
					'Name': ['Rashmi', 'Arun', 'John',
							'Kshitu', 'Bresha'],
					'Roll No': ['1', '2', '3', '4', '5']})

B = pd.DataFrame({'Sr.no': ['2', '4', '6', '7', '8'],
					'Gender': ['F', 'M', 'M', 'F', 'F'],
					'Interest': ['Writing', 'Cricket', 'Dancing',
								'Chess', 'Sleeping']})

# %%
A
# Out:
#   Sr.no    Name Roll No
# 0     1  Rashmi       1
# 1     2    Arun       2
# 2     3    John       3
# 3     4  Kshitu       4
# 4     5  Bresha       5

# %%
B
# Out:
#   Sr.no Gender  Interest
# 0     2      F   Writing
# 1     4      M   Cricket
# 2     6      M   Dancing
# 3     7      F     Chess
# 4     8      F  Sleeping

# %%
surya=B[B['Gender']=='M'] #filtering the data

# %%
surya
# Out:
#   Sr.no Gender Interest
# 1     4      M  Cricket
# 2     6      M  Dancing

# %%
x=['Cricket','Chess']
D=B[B.Interest.isin(x)] #another way to filter data with more columns

# %%
#concat

# %%
pd.concat([A,B])
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2    NaN       NaN
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4    NaN       NaN
# 4     5  Bresha       5    NaN       NaN
# 0     2     NaN     NaN      F   Writing
# 1     4     NaN     NaN      M   Cricket
# 2     6     NaN     NaN      M   Dancing
# 3     7     NaN     NaN      F     Chess
# 4     8     NaN     NaN      F  Sleeping

# %%
A
# Out:
#   Sr.no    Name Roll No
# 0     1  Rashmi       1
# 1     2    Arun       2
# 2     3    John       3
# 3     4  Kshitu       4
# 4     5  Bresha       5

# %%
B
# Out:
#   Sr.no Gender  Interest
# 0     2      F   Writing
# 1     4      M   Cricket
# 2     6      M   Dancing
# 3     7      F     Chess
# 4     8      F  Sleeping

# %%
merge1=A.merge(B)

# %%
merge1
# Out:
#   Sr.no    Name Roll No Gender Interest
# 0     2    Arun       2      F  Writing
# 1     4  Kshitu       4      M  Cricket

# %%
pd.merge(A,B,on='Sr.no',how='left')
# Out:
#   Sr.no    Name Roll No Gender Interest
# 0     1  Rashmi       1    NaN      NaN
# 1     2    Arun       2      F  Writing
# 2     3    John       3    NaN      NaN
# 3     4  Kshitu       4      M  Cricket
# 4     5  Bresha       5    NaN      NaN

# %%
pd.merge(A,B,on='Sr.no',how='right')
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     2    Arun       2      F   Writing
# 1     4  Kshitu       4      M   Cricket
# 2     6     NaN     NaN      M   Dancing
# 3     7     NaN     NaN      F     Chess
# 4     8     NaN     NaN      F  Sleeping

# %%
pd.merge(A,B,on='Sr.no',how='outer')
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2      F   Writing
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4      M   Cricket
# 4     5  Bresha       5    NaN       NaN
# 5     6     NaN     NaN      M   Dancing
# 6     7     NaN     NaN      F     Chess
# 7     8     NaN     NaN      F  Sleeping

# %%
pd.merge(A,B,on='Sr.no',how='inner')
# Out:
#   Sr.no    Name Roll No Gender Interest
# 0     2    Arun       2      F  Writing
# 1     4  Kshitu       4      M  Cricket

# %%
df1
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2      F   Writing
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4      M   Cricket
# 4     5  Bresha       5    NaN       NaN
# 5     6     NaN     NaN      M   Dancing
# 6     7     NaN     NaN      F     Chess
# 7     8     NaN     NaN      F  Sleeping

# %%
df1.isnull()
# Out:
#    Sr.no   Name  Roll No  Gender  Interest
# 0  False  False    False    True      True
# 1  False  False    False   False     False
# 2  False  False    False    True      True
# 3  False  False    False   False     False
# 4  False  False    False    True      True
# 5  False   True     True   False     False
# 6  False   True     True   False     False
# 7  False   True     True   False     False

# %%
df1['Name'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# Name: Name, dtype: bool

# %%
df1
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2      F   Writing
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4      M   Cricket
# 4     5  Bresha       5    NaN       NaN
# 5     6     NaN     NaN      M   Dancing
# 6     7     NaN     NaN      F     Chess
# 7     8     NaN     NaN      F  Sleeping

# %%
df2=df1['Name'].dropna()

# %%
df2
# Out:
# 0    Rashmi
# 1      Arun
# 2      John
# 3    Kshitu
# 4    Bresha
# Name: Name, dtype: object

# %%
df3=df1['Gender'].fillna(0)

# %%
df3
# Out:
# 0    0
# 1    F
# 2    0
# 3    M
# 4    0
# 5    M
# 6    F
# 7    F
# Name: Gender, dtype: object

# %%
df1
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2      F   Writing
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4      M   Cricket
# 4     5  Bresha       5    NaN       NaN
# 5     6     NaN     NaN      M   Dancing
# 6     7     NaN     NaN      F     Chess
# 7     8     NaN     NaN      F  Sleeping

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df1.drop_duplicates()
# Out:
#   Sr.no    Name Roll No Gender  Interest
# 0     1  Rashmi       1    NaN       NaN
# 1     2    Arun       2      F   Writing
# 2     3    John       3    NaN       NaN
# 3     4  Kshitu       4      M   Cricket
# 4     5  Bresha       5    NaN       NaN
# 5     6     NaN     NaN      M   Dancing
# 6     7     NaN     NaN      F     Chess
# 7     8     NaN     NaN      F  Sleeping
